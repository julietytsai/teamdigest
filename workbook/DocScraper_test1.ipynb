# %% [markdown]
# ### Run tests on the 16 companies

# %%
from docscraping import DocScraper
import requests
import re
import html
from cikscraping import CIKScraper
from webscraping import SECScraper
from sec_api import ExtractorApi
import pandas as pd

# %%
def text_preprocessing(text):
    text = html.unescape(text)

    # TABLE_START and ##TABLE_END
    text = re.sub(r'##TABLE_START|##TABLE_END', '', text)

    text = re.sub(r'END', '', text)

    text = re.sub(r'\xa0', '', text)

    text = re.sub(r'\n\n', '', text)

    text = re.sub(r'&#8217;', '', text)

    return text

# %%
headers = {"User-Agent": "bxie43@wisc.edu"}
FILE = '10-K'
Year = '2023'
api_key = 'caa74af7cfc61540b005c834f22857591cd78425cb1731fd70b9afdb201852fd'

# %% [markdown]
# ##### 1. ADM

# %%
company = CIKScraper("ADM", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year, 'ADM')
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions)
# Out:
# Regulatory Compliance: dict_keys(['Regulatory Risks'])
# Product Portfolio: dict_keys(['Company Overview ', 'Segment Descriptions ', 'Ag Services and Oilseeds ', 'Carbohydrate Solutions ', 'Nutrition ', 'Other Business ', 'Corporate ', 'Methods of Distribution ', 'Concentration of Revenues by Product ', 'Status of New Products ', 'Source and Availability of Raw Materials ', 'Trademarks, Brands, Recipes, and other Intellectual Property ', 'Seasonality, Working Capital Needs, and Significant Customers ', 'Competition ', 'Research and Development ', 'Governance ', 'Strategy ', 'Scenario Analysis ', 'Products and Services Opportunities ', 'Risk Management ', 'Metrics and Targets ', 'Income Taxes ', 'Human Capital and Diversity and Inclusion ', 'Number of Employees by Contract and Region ', 'Number of Employees by Type and Gender ', 'Percentage of Employees by Level and Gender ', 'Compensation and Benefits ', 'Employee Development ', 'Workplace Safety ', 'Available Information '])
# ...

# %%
company = CIKScraper("KDSKF", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_60480\304610548.py in <module>
#       1 company = CIKScraper("KDSKF", headers)
# ----> 2 company.parsing_tickers()
#       3
#       4 scraper = SECScraper(company.cik, Year, FILE, headers)
#       5 url = scraper.scrape_sec_data()
#
# c:\Users\xben4\Desktop\MSBA\GB 790\github_projects\teamdigest-1\cikscraping.py in parsing_tickers(self)
#      17         tickers_cik["cik_str"] = tickers_cik["cik_str"].astype(str)
#      18         ticker_table = tickers_cik[tickers_cik["ticker"]==self.ticker]
# ---> 19         self.cik = ticker_table["cik_str"].values[0]
#      20         self.company = ticker_table["title"].values[0]
#      21         return ticker_table
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
parser.regulatorycompliance[list(parser.regulatorycompliance.keys())[0]]
# Out:
# ' \n\nThe Company is subject to numerous laws, regulations, and mandates globally which could adversely affect the Company’s operating results and forward strategy. \n\nThe Company does business globally, connecting crops and markets in over 190 countries, and is required to comply with laws and regulations administered by the United States federal government as well as state, local, and non-U.S. governmental authorities in numerous areas including: accounting and income taxes, anti-corruption, anti-bribery, global trade, trade sanctions, privacy and security, environmental, product safety, and handling and production of regulated substances. The Company frequently faces challenges from U.S. and foreign tax authorities regarding the amount of taxes due including questions regarding the timing, amount of deductions, the allocation of income among various tax jurisdictions, and further risks related to changing tax laws domestically and globally. Any failure to comply with applicable l
# ...

# %%
parser.productportfolio['Ag Services and Oilseeds ']
# Out:
# ['The Ag Services and Oilseeds segment includes global activities related to the origination, merchandising, transportation, and storage of agricultural raw materials, and the crushing and further processing of oilseeds such as soybeans and soft seeds (cottonseed, sunflower seed, canola, rapeseed, and flaxseed) into vegetable oils and protein meals. Oilseeds products produced and marketed by the segment include ingredients for food, feed, energy, and industrial customers. Crude vegetable oils produced by the segment&#8217;s crushing activities are sold &#8220;as is&#8221; to manufacturers of renewable green diesel and other customers or are further processed by refining, blending, bleaching, and deodorizing into salad oils. Salad oils are sold &#8220;as is&#8221; or are further processed by hydrogenating and/or interesterifying into margarine, shortening, and other food products. Partially refined oils are used to produce biodiesel and glycols or are sold to other manufacturers for u
# ...

# %%
years = ['2021','2022','2023']
df = pd.DataFrame()
for year in years:
    scraper = SECScraper(company.cik, year, FILE, headers)
    url = scraper.scrape_sec_data()[0]
    parser = DocScraper(url, FILE, headers, api_key, year, 'ADM')
    parser.parsing_file()
    data = {
        'Year':[year],
        'Ticker':[parser.ticker],
        'Product_Portfolio':[list(parser.productportfolio.keys())],
        'Regulatory_Compliance':[parser.regulatorycompliance[list(parser.regulatorycompliance.keys())[0]]],
        'Competitive_Analysis':[parser.acquisitions]
    }
    df1 = pd.DataFrame(data)
    df = pd.concat([df, df1], axis = 0)
df
# Out:
#    Year Ticker                                  Product_Portfolio  \
# 0  2021    ADM  [Company Overview , Segment Descriptions , Ag ...
# 0  2022    ADM  [Company Overview , Segment Descriptions , Ag ...
# 0  2023    ADM  [Company Overview , Segment Descriptions , Ag ...
#
#                                Regulatory_Compliance  \
# 0   \n\nThe Company is subject to numerous laws, ...
# 0   \n\nThe Company is subject to numerous laws, ...
# 0   \n\nThe Company is subject to numerous laws, ...
#
#                                 Competitive_Analysis
# 0  [ (In millions) Year Ended December 31  2020 2...
# 0  [ (In millions) Year Ended December 31  2021 2...
# 0  [ (In millions) Year Ended December 31  2022 2...

# %%
df2= pd.DataFrame(parser.productportfolio)
df2.iloc[:, 2]
# Out:
# 0    The Ag Services and Oilseeds segment includes ...
# Name: Ag Services and Oilseeds , dtype: object

# %%
df2.iloc[0, 2]
# Out:
# 'The Ag Services and Oilseeds segment includes global activities related to the origination, merchandising, transportation, and storage of agricultural raw materials, and the crushing and further processing of oilseeds such as soybeans and soft seeds (cottonseed, sunflower seed, canola, rapeseed, and flaxseed) into vegetable oils and protein meals. Oilseeds products produced and marketed by the segment include ingredients for food, feed, energy, and industrial customers. Crude vegetable oils produced by the segment&#8217;s crushing activities are sold &#8220;as is&#8221; to manufacturers of renewable green diesel and other customers or are further processed by refining, blending, bleaching, and deodorizing into salad oils. Salad oils are sold &#8220;as is&#8221; or are further processed by hydrogenating and/or interesterifying into margarine, shortening, and other food products. Partially refined oils are used to produce biodiesel and glycols or are sold to other manufacturers for us
# ...

# %%
year = '2022'
scraper = SECScraper(company.cik, year, FILE, headers)
url = scraper.scrape_sec_data()[0]
parser = DocScraper(url, FILE, headers, api_key, year, 'ADM')
parser.parsing_file()
data = {
    'Year':[year],
    'Ticker':[parser.ticker],
    'Product_Portfolio':parser.productportfolio['Ag Services and Oilseeds '],
    'Regulatory_Compliance':[parser.regulatorycompliance[list(parser.regulatorycompliance.keys())[0]]],
    'Competitive_Analysis':[parser.acquisitions]
}
print("Year is:", year)
df1 = pd.DataFrame(data)l
df1
# Out:
# Year is: 2022
#    Year Ticker                                  Product_Portfolio  \
# 0  2022    ADM  The Ag Services and Oilseeds segment includes ...
#
#                                Regulatory_Compliance  \
# 0   \n\nThe Company is subject to numerous laws, ...
#
#                                 Competitive_Analysis
# 0  [ (In millions) Year Ended December 31  2021 2...

# %%
year = '2023'
scraper = SECScraper(company.cik, year, FILE, headers)
url = scraper.scrape_sec_data()[0]
parser = DocScraper(url, FILE, headers, api_key, year, 'ADM')
parser.parsing_file()
data = {
    'Year':[year],
    'Ticker':[parser.ticker],
    'Product_Portfolio':parser.productportfolio['Ag Services and Oilseeds '],
    'Regulatory_Compliance':[parser.regulatorycompliance[list(parser.regulatorycompliance.keys())[0]]],
    'Competitive_Analysis':[parser.acquisitions]
}
print("Year is:", year)
df2 = pd.DataFrame(data)
df2
# Out:
# Year is: 2023
#    Year Ticker                                  Product_Portfolio  \
# 0  2023    ADM  The Ag Services and Oilseeds segment includes ...
#
#                                Regulatory_Compliance  \
# 0   \n\nThe Company is subject to numerous laws, ...
#
#                                 Competitive_Analysis
# 0  [ (In millions) Year Ended December 31  2022 2...

# %%
df = pd.concat([df1, df2], axis = 0)
df
# Out:
#    Year Ticker                                  Product_Portfolio  \
# 0  2022    ADM  The Ag Services and Oilseeds segment includes ...
# 0  2023    ADM  The Ag Services and Oilseeds segment includes ...
#
#                                Regulatory_Compliance  \
# 0   \n\nThe Company is subject to numerous laws, ...
# 0   \n\nThe Company is subject to numerous laws, ...
#
#                                 Competitive_Analysis
# 0  [ (In millions) Year Ended December 31  2021 2...
# 0  [ (In millions) Year Ended December 31  2022 2...

# %%
company = CIKScraper("BGS", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year, 'BGS')
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Our ability to make interest payments on and to refinance our indebtedness, and to fund working capital needs, planned capital expenditures and potential acquisitions depends on our ability to generate cash flow from operations in the future. This ability, to a certain extent, is subject to general economic, financial, competitive, legislative, regulatory and other factors that are beyond our control. ', 'Climate change, water scarcity or legal, regulatory, or market measures to address climate change or water scarcity, could negatively affect our business and operations. ', 'The increasing concern over climate change also may result in more regional, federal, foreign and/or global legal and regulatory requirements to reduce or mitigate the effects of greenhouse gases. In the event that such regulation is enacted and is more aggressive than the sustainability measures that we are currently undertaking to monitor our emissions, improve our energy and
# ...

# %%
parser.regulatorycompliance.values()
# Out:
# dict_values(['\n\nWe could be subject to adverse publicity or claims from consumers. \n\nCertain of our products contain ingredients which are the subject of public scrutiny, including the suggestion that consumption may have adverse health effects. Although we strive to respond to consumer preferences and social expectations, we may not be successful in these efforts. An unfavorable report on the effects of ingredients present in our products, product recalls, such as the Jif peanut butter product recall, or negative publicity or litigation could influence consumer preferences, significantly reduce the demand for our products, and adversely affect our profitability. \n\nWe may also be subject to complaints from or litigation by consumers who allege food and beverage-related illness, or other quality, health, or operational concerns. Adverse publicity resulting from such allegations could materially adversely affect us, regardless of whether such allegations are true or whether we ar
# ...

# %%
text = parser.item1a
pattern = r'\n\n([^\n]+regulatory[^\n]+)\s+'
matches = re.findall(pattern, text, re.IGNORECASE)
matches
# Out:
# ['Our ability to make interest payments on and to refinance our indebtedness, and to fund working capital needs, planned capital expenditures and potential acquisitions depends on our ability to generate cash flow from operations in the future. This ability, to a certain extent, is subject to general economic, financial, competitive, legislative, regulatory and other factors that are beyond our control. ',
#  'Climate change, water scarcity or legal, regulatory, or market measures to address climate change or water scarcity, could negatively affect our business and operations. ',
# ...

# %%
text = parser.item1a
# Define a regular expression pattern to capture risks and their descriptions
pattern = r'\n\n(.*?)\n\n'

# Find all matches in the text
matches = re.findall(pattern, text, re.DOTALL)

relevant_matches = []

for i in range(len(matches) - 1):
    current_match = matches[i]
    next_match = matches[i + 1]

    if any(keyword in current_match.lower() for keyword in ["regulatory", "regulation", "regulations", "comply", "compliance"]):
        relevant_matches.append(current_match)
        relevant_matches.append(next_match)

# Print the relevant matches
for match in relevant_matches:
    print(match)

# %% [markdown]
# #### 3. BEYOND MEAT

# %%
company = CIKScraper("BYND", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys([])
# Product Portfolio: dict_keys(['Overview ', 'Our Mission ', 'The Beyond Meat Strategic Difference ', 'Our Industry and Market Opportunity ', 'Our Competitive Strengths ', 'Cost Down Strategy ', 'Our Products ', 'Customers ', 'Our Supply Chain ', 'Manufacturing ', 'Quality Control ', 'Distribution ', 'Order Fulfillment ', 'Competition ', 'Research and Development ', 'Product Innovation ', 'Seasonality ', 'Human Capital Resources ', 'Trademarks and Other Intellectual Property ', 'Segments ', 'Government Regulation ', 'Corporate Information ', 'Emerging Growth Company Status ', 'Our Website and Availability of SEC Reports and Other Information '])
# ...

# %%
text
# Out:
# " ITEM 1A. RISK FACTORS. \n\nRisk Factor Summary \n\nWe are providing the following summary of the risk factors contained in this report to enhance the readability and accessibility of our risk factor disclosures. We encourage you to carefully review the full risk factors immediately following this summary as well as the other information in this report, including the section titled &#8220; Management&#8217;s Discussion and Analysis of Financial Condition and Results of Operations, &#8221; &#8220; Note Regarding Forward-Looking Statements ,&#8221; and our consolidated financial statements and related notes, before deciding whether to invest in shares of our common stock. The risks and uncertainties described in this report may not be the only ones we face. If any of the risks actually occurs, our business, financial condition, operating results, cash flows and prospects could be materially and adversely affected. In this case, the trading price of our common stock would likely declin
# ...

# %%
text = parser.item1a
text = text_preprocessing(text)
text
# Out:
# " ITEM 1A. RISK FACTORS. \n\nRisk Factor Summary \n\nWe are providing the following summary of the risk factors contained in this report to enhance the readability and accessibility of our risk factor disclosures. We encourage you to carefully review the full risk factors immediately following this summary as well as the other information in this report, including the section titled “ Management’s Discussion and Analysis of Financial Condition and Results of Operations, ” “ Note Regarding Forward-Looking Statements ,” and our consolidated financial statements and related notes, before deciding whether to invest in shares of our common stock. The risks and uncertainties described in this report may not be the only ones we face. If any of the risks actually occurs, our business, financial condition, operating results, cash flows and prospects could be materially and adversely affected. In this case, the trading price of our common stock would likely decline and you might lose part or a
# ...

# %%
pattern = r'\n\n(Risks Related to [^\n]+)\s+'
matches = re.findall(pattern, text, re.IGNORECASE)
matches
# Out:
# ['Risks Related to Our Business ',
#  'Risks Related to Our Products ',
#  'Risks Related to Our Industry and Brand ',
#  'Risks Related to Our International Operations ',
#  'Risks Related to Our Investments ',
#  'Risks Related to Our Intellectual Property, Information Technology, Cybersecurity and Privacy ',
#  'Risks Related to Our Lease Obligations, Indebtedness, Financial Position and Need for Additional Capital ',
#  'Risks Related to the Environment, Climate and Weather ',
#  'Risks Related to Being a Public Company ',
#  'Risks Related to Regulatory and Legal Compliance Matters, Litigation and Legal Proceedings ']

# %%
pattern = '|'.join(re.escape(match) for match in matches)

risks_dict = {}
text_segments = re.split(pattern, text)[11:] # Duplicates
text_segments
# Out:
# ['\n\nDisruptions in the worldwide economy, including an economic recession, downturn, periods of inflation or economic uncertainty, have and may continue to adversely affect our business, results of operations and financial condition. \n\nThe global economy can be negatively impacted by a variety of factors such as the spread or fear of spread of contagious diseases (such as the COVID-19 pandemic, other pandemics, epidemics or other public health crises) in locations where our products are sold, man-made or natural disasters, severe weather, actual or threatened hostilities or war, terrorist activity, political unrest, civil strife and other geopolitical uncertainty. Such adverse and uncertain economic conditions may impact distributor, retailer, foodservice and consumer demand for our products. For example, in connection with the war in Ukraine, governments in the U.S., U.K. and the EU have each imposed export controls on certain products and financial and economic sanctions on cer
# ...

# %%
for title, text in zip(matches, text_segments):
    risks_dict[title] = text

regulatory_compliance = {key: value for key, value in risks_dict.items() if "legal" in key.lower() or "regulatory" in key.lower() or "regulation" in key.lower()}
regulatory_compliance
# Out:
# {'Risks Related to Regulatory and Legal Compliance Matters, Litigation and Legal Proceedings ': '\n\nOur operations are subject to FDA governmental regulation and other foreign, federal, state and local regulation, and there is no assurance that we will be in compliance with all regulations. \n\nOur operations are subject to extensive regulation by the FDA, and other foreign, federal, state and local authorities. Specifically, for products manufactured or sold in the United States we are subject to the requirements of the Federal Food, Drug and Cosmetic Act and regulations promulgated thereunder by the FDA. \n\nThis comprehensive regulatory program governs, among other things, the manufacturing, composition and ingredients, packaging, labeling and safety of food. Under this program, the FDA requires that facilities that manufacture food products comply with a range of requirements, including hazard analysis and preventive controls regulations, current good manufacturing practices (“c
# ...

# %%
regulatory_compliance.keys()
# Out:
# dict_keys(['Risks Related to Regulatory and Legal Compliance Matters, Litigation and Legal Proceedings '])

# %% [markdown]
# #### 4. Brown-Forman Corp.

# %%
company = CIKScraper("BF-B", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Legal and Regulatory Risks'])
# Product Portfolio: dict_keys(['Overview ', 'Brands ', 'Markets ', 'Distribution Network and Customers ', 'Seasonality ', 'Competition ', 'Ingredients and Other Supplies ', 'Distilled Spirits Liqueurs RTD Products Wines Packaging Agave Flavorings Carbon dioxide Grapes Aluminum cans Barley Neutral spirits Flavorings Wood Cartons Corn Sugar Malt Closures Malted barley Water Neutral spirits Glass bottles Molasses Whiskey Sugar Labels Rye Wine Tequila ', 'Intellectual Property ', 'Regulatory Environment ', 'Integrated Strategy and Performance ', 'Portfolio and Responsibility ', 'Geography ', 'Investment and Sustainability ', 'Community ', 'Human Capital Resources ', 'Total Rewards ', 'Talent Development ', 'Workforce Stability ', 'Executive Officers ', 'Available Information '])
# ...

# %%
text = parser.item1a


# Define a regular expression pattern to capture risks and their descriptions
pattern = r'\n\n(Risks Relat\w+? to [^\n]+)\s+'

# Find all matches in the text
matches = re.findall(pattern, text)
matches
# Out:
# ['Risks Related to Our Business and Operations ',
#  'Risks Related to Our Global Operations ',
#  'Risks Related to Cybersecurity and Data Privacy ',
#  'Risks Related to Our Ownership and Corporate Governance Structure ']

# %% [markdown]
# #### 5. BUNGE NORTH AMERICA

# %%
company = CIKScraper("BG", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year, "BG")
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25348\864455880.py in <module>
#       3
#       4 scraper = SECScraper(company.cik, Year, FILE, headers)
# ----> 5 url = scraper.scrape_sec_data()[0]
#       6
#       7 parser = DocScraper(url, FILE, headers, api_key, Year, "BG")
#
# IndexError: list index out of range

# %%
company.ticker
# Out:
# 'BG'

# %%
company = CIKScraper("BG", headers)
company.parsing_tickers()
company.cik
# Out:
# '1996862'

# %%
text = parser.item1a
# Define a regular expression pattern to capture risks and their descriptions
pattern = r'\n\n(Risks Relat\w+? to [^\n]+)\s+'

# Find all matches in the text
matches = re.findall(pattern, text)
matches
# Out:
# ['Risks Relating to Our Business and Industries ',
#  'Risks Relating to the Redomestication ',
#  'Risks Relating to Our Common Shares ']

# %%
pattern = '|'.join(re.escape(match) for match in matches)

risks_dict = {}
text_segments = re.split(pattern, text)[1:]

for title, text in zip(matches, text_segments):
    risks_dict[title] = text

regulatory_compliance = {key: value for key, value in risks_dict.items() if "legal" in key.lower() or "regulatory" in key.lower() or "regulation" in key.lower()}


# Nothing contains "legal" or "regulatory" in risks_dict
regulatory_compliance = {key: value for key, value in risks_dict.items() if "legal" in value.lower() or "regulatory" in value.lower() or "regulation" in value.lower()}
regulatory_compliance
# Out:
# {'Risks Relating to Our Business and Industries ': '\n\nOur operations have been and may in the future be adversely impacted as a result of pandemic outbreaks, including COVID-19. \n\nThe COVID-19 pandemic has had, and continues to have, a significant impact around the world causing a disruption of global financial markets and increased levels of unemployment and economic uncertainty. Since early 2020, government officials around the world, including in the countries where we operate, have imposed measures in response to the pandemic, including vaccination and masking requirements, protocols related to workplace activities, travel and large gathering \n\nTabl e of Contents \n\nrestrictions, social distancing requirements, quarantines and shelter-in-place and stay-at-home orders. Certain of these restrictions remain in place today. The COVID-19 pandemic has curtailed global economic activity and caused significant volatility and disruption in global financial markets. During the cours
# ...

# %%
parser.item8
# Out:
# ' Item 8. Financial Statements and Supplementary Data \n\nOur financial statements and related schedule required by this item are contained on pages F-1 through F-73 and on page E-1 included as part of this Annual Report on Form 10-K. See Item 15(a) for a listing of financial statements provided. \n\n'

# %%
text = text_preprocessing(parser.item8)
text
# Out:
# ' Item 8. Financial Statements and Supplementary Data \n\nOur financial statements and related schedule required by this item are contained on pages F-1 through F-73 and on page E-1 included as part of this Annual Report on Form 10-K. See Item 15(a) for a listing of financial statements provided. \n\n'

# %% [markdown]
# #### 6. Campbell Soup Co.

# %%
company = CIKScraper("CPB", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Legal and Regulatory Risks'])
# Product Portfolio: dict_keys(['The Company ', 'Reportable Segments ', 'Ingredients and Packaging ', 'Customers ', 'Trademarks and Technology ', 'Competition ', 'Capital Expenditures ', 'Government Regulation ', 'Environmental Matters ', 'Seasonality ', 'Human Capital Management ', 'Training, Development and Engagement ', 'Inclusion and Diversity ', 'Wellness and Safety ', 'Total Rewards ', 'Websites '])
# ...

# %% [markdown]
# #### 7. Colagate-Palmolive Co.

# %%
company = CIKScraper("CL", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year, 'CL')
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Legal and Regulatory Risks'])
# Product Portfolio: dict_keys(['Government Regulations ', 'Human Capital Management ', 'Succession Planning ', 'Compensation Philosophy ', 'Sustainability ', 'Information about our Executive Officers '])
# acquisitions: [' ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY DATA \n\nSee &#8220;Index to Financial Statements.&#8221; \n\n']

# %%
parser.item1a
# Out:
# ' ITEM 1A. RISK FACTORS \n\nIn addition to the risks described elsewhere in this report, set forth below is a summary of the material risks to an investment in our securities. These risks, some of which have occurred and/or are occurring and any of which could occur in the future, are not the only ones we face. Additional risks not presently known to us or that we currently deem immaterial may also have an adverse effect on us. If any of these risks actually occur, our business, results of operations, cash flows and financial condition could be materially and adversely impacted, which might cause the value of our securities to decline. \n\nBusiness and Industry Risks \n\nWe face risks associated with significant international operations, including exposure to foreign currency fluctuations. \n\nWe operate on a global basis serving consumers in more than 200 countries and territories with approximately two-thirds of our Net sales originating in markets outside the U.S. While geographic
# ...

# %% [markdown]
# #### 8. Conagra

# %%
company = CIKScraper("CAG", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Legal, Regulatory, and Environmental Risks'])
# Product Portfolio: dict_keys(['General Development of Business ', 'Narrative Description of Business ', 'Reporting Segments ', 'International ', 'Foodservice ', 'Unconsolidated Equity Investments ', 'General ', 'Human Capital Resources ', 'Information About Our Executive Officers ', 'Appointed an ', 'Officer ', 'Charisse Brock', 'Foreign Operations ', 'Available Information '])
# ...

# %% [markdown]
# #### 9. Corteva/Dow Agrosciences

# %%
company = CIKScraper("CTVA", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year, 'CTVA')
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Risks Related to our Industry ', 'Risks Related to Our Operations ', 'Risks Related to Our Intellectual Property ', 'Risks Related to The Separation '])
# Product Portfolio: dict_keys(['Background ', 'Internal Reorganizations and Business Separations ', 'Part I ', 'Separation Agreements ', 'Business Segments ', 'Seed ', 'Products and Brands ', 'Seed Solutions Traits and Technologies ', 'Other ', 'Distribution ', 'Key Raw Materials ', 'Crop Protection ', 'Disease Management ', 'Weed Control ', 'Nitrogen Management ', 'Seasonality ', 'Human Capital Management ', 'Intellectual Property ', 'Competition ', 'Environmental Matters ', 'Regulatory Considerations ', 'Regulation of Crop Protection Products ', 'European Farm to Fork Strategy ', 'Available Information '])
# ...

# %%
parser.acquisitions
# Out:
# [' ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY DATA \n\nThe financial statements and supplementary data required by this Item are included herein, commencing on page F-1 of this report. \n\n']

# %%
text = parser.item1a
pattern = r'\n\n(Risks Related to [^\n]+)\s+'
matches = re.findall(pattern, text)

pattern = '|'.join(re.escape(match) for match in matches)

risks_dict = {}
text_segments = re.split(pattern, text)[1:]

for title, text in zip(matches, text_segments):
    risks_dict[title] = text

regulatory_compliance = {key: value for key, value in risks_dict.items() if "legal" in key.lower() or "regulatory" in key.lower() or "regulation" in key.lower()}
regulatory_compliance
# Out:
# {}

# %%
risks_dict
# Out:
# {'Risks Related to our Industry ': "\n\nThe successful development and commercialization of Corteva's pipeline products will be necessary for Corteva's growth. \n\nCorteva uses advanced breeding technologies to produce hybrids and varieties with superior performance in farmers&#8217; fields and uses biotechnology to introduce traits that enhance specific characteristics of its crops. Corteva also uses advanced analytics, software tools, mobile communications and new planting and monitoring equipment to provide agronomic recommendations to growers. Additionally, Corteva conducts research into biological and chemical products to protect farmers&#8217; crops from pests and diseases and enhance plant productivity. \n\nNew product concepts may be abandoned for many reasons, including greater anticipated development costs, technical difficulties, lack of efficacy, regulatory obstacles or inability to market under regulatory frameworks, competition, inability to prove the original concept, 
# ...

# %% [markdown]
# #### 10. General Mills Inc.

# %%
company = CIKScraper("GIS", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Legal and Regulatory Risks'])
# ...

# %% [markdown]
# #### 11. Ingredion

# %%
company = CIKScraper("INGR", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11156\2890462508.py in <module>
# ----> 1 company = CIKScraper("INGR", headers)
#       2 company.parsing_tickers()
#       3
#       4 scraper = SECScraper(company.cik, Year, FILE, headers)
#       5 url = scraper.scrape_sec_data()[0]
#
# NameError: name 'CIKScraper' is not defined

# %%
text = parser.item1a
pattern = r'[A-Z][A-Za-z,\s]* Risks'
# pattern = r'\n\n(Risks Related to [^\n]+) ' # Delete "Our" to match SJM
matches = re.findall(pattern, text)
matches
# Out:
# ['Legal and Regulatory Risks']

# %%
risks_dict = {}
text_segments = re.split(pattern, text)[1:]
# Iterate through both lists and match them accordingly
for title, text in zip(matches, text_segments):
    risks_dict[title] = text

regulatory_compliance = {key: value for key, value in risks_dict.items() if "legal" in key.lower() or "regulatory" in key.lower() or "regulation" in key.lower()}
regulatory_compliance
# Out:
# {'Risks Related to Our Regulatory Compliance': '\n\nOur business may be adversely affected by impacts on the availability and prices of raw materials and energy supplies, volatility in foreign exchange and interest rates, and other effects of the conflict between Russia and Ukraine. \n\nOur business may be adversely affected by the effects of the ongoing conflict between Russia and Ukraine. Although our operations in Russia and Ukraine accounted for less than one half of one percent of our net sales in fiscal year 2022, the region is a source of raw material and energy supply for both us and certain companies whose products we distribute. Economic sanctions and export control measures imposed on Russia and designated Russian enterprises, Belarus and certain regions of Ukraine have resulted in increased volatility in the availability and prices of such raw materials and energy supplies. In addition, sanctions and macroeconomic effects of the conflict have contributed to greater volati
# ...

# %% [markdown]
# #### 12. Kraft Heinz Co.

# %%
company = CIKScraper("KHC", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Regulatory Risks'])
# Product Portfolio: dict_keys(['General ', 'Resources ', 'Research and Development ', 'Competition ', 'Sales ', 'Seasonality ', 'Government Regulation ', 'Human Capital Management ', 'Information about our Executive Officers ', 'Miguel Patricio, ', 'Andre Maciel, ', 'Executive Vice President and President, North America ', 'Kathy Krenger, ', 'Rashida La Lande, ', 'Marcos Eloi Lima, ', 'Rafael Oliveira, ', 'Executive Vice President and Global Chief Supply Chain Officer ', 'Melissa Werneck, ', 'Yang Xu ', 'Available Information '])
# ...

# %% [markdown]
# #### 13. MONDAVI WINERY/CONSTELLATION

# %%
company = CIKScraper("STZ", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys([])
# ...

# %%
text = parser.item1a

# Remove 
text = re.sub(r'\n\n', '', text)

# Define a regular expression pattern to capture risks and their descriptions
pattern = r'[A-Z][A-Za-z,\s]* Risks'

# Find all matches in the text
matches = re.findall(pattern, text)
matches
# Out:
# ['Operational Risks',
#  'ENDStrategic Risks',
#  'Financial Risks',
#  'ENDOther Risks',
#  'General Risks International operations, worldwide and regional economic trends and financial market conditions, geopolitical uncertainty, or other governmental rules and regulations Risks']

# %%
risks_dict = {}
text_segments = re.split(pattern, text)[1:]
text_segments
# Out:
# [' Supply of quality water, agricultural, and other raw materials, certain raw and packaging materials purchased under supply contracts; supply chain disruptions and inflation; limited group of glass bottle suppliers The quality and quantity of water available for use is important to the supply of our agricultural raw materials and our ability to operate our business. Water is a limited resource in many parts of the world. If climate patterns change and droughts continue or become more severe or other restrictions on currently available water resources are imposed, there may be a scarcity of water or poor water quality which may affect our and our suppliers&#8217; operations, increase production costs, or impose capacity constraints. We are dependent on sufficient amounts of quality water for operation of our breweries, wineries, and distilleries, as well as to irrigate our vineyards and conduct our other operations. The suppliers of the agricultural raw materials we purchase are als
# ...

# %%
# Iterate through both lists and match them accordingly
for title, text in zip(matches, text_segments):
    risks_dict[title] = text

regulatory_compliance = {key: value for key, value in risks_dict.items() if "legal" in key.lower() or "regulatory" in key.lower() or "regulation" in key.lower()}
regulatory_compliance
# Out:
# {'General Risks International operations, worldwide and regional economic trends and financial market conditions, geopolitical uncertainty, or other governmental rules and regulations Risks': ' associated with international operations, any of which could have a material adverse effect on our business, liquidity, financial condition, and/or results of operations, include: &#8226; changes in political, economic, social, and labor conditions in U.S. and international locales; &#8226; potential disruption from wars and military conflicts, including Russia&#8217;s invasion of Ukraine, terrorism, civil unrest, kidnapping, and drug-related, workplace, or other types of violence; &#8226; restrictions on foreign ownership and investments or on repatriation of cash earned in countries outside the U.S.; &#8226; import and export requirements and border accessibility; &#8226; protectionist trade policies, sanctions, and tariffs; &#8226; foreign currency exchange rate fluctuations, which may redu
# ...

# %% [markdown]
# #### 14. Mondelez International

# %%
company = CIKScraper("MDLZ", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Legal and Regulatory Risks'])
# Product Portfolio: dict_keys(['General ', 'Strategy ', 'Table of Contents ', 'Global Operations ', 'Reportable Segments ', 'Product Categories ', 'Seasonality ', 'Distribution and Marketing ', 'Research, Development and Innovation ', 'Competition ', 'Raw Materials and Packaging ', 'Human Capital ', 'Sustainability and Mindful Snacking ', 'Regulation ', 'Information about our Executive Officers ', 'Ethics and Governance ', 'Available Information '])
# ...

# %% [markdown]
# #### 15. PepsiCo Inc.

# %%
company = CIKScraper("PEP", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year)
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Tax and Regulatory Risks'])
# Product Portfolio: dict_keys(['Company Overview ', 'Our Operations ', 'Quaker Foods North America ', 'PepsiCo Beverages North America ', 'Latin America ', 'Europe ', 'Africa, Middle East and South Asia ', 'Asia Pacific, Australia and New Zealand and China Region ', 'Our Distribution Network ', 'Customer Warehouse ', 'Distributor Networks ', 'Ingredients and Other Supplies ', 'Our Brands and Intellectual Property Rights ', 'Seasonality ', 'Our Customers ', 'Our Competition ', 'Research and Development ', 'Regulatory Matters ', 'Human Capital ', 'Available Information '])
# acquisitions: []

# %% [markdown]
# #### 16. Tyson Foods Inc

# %%
# No annual report in year 2023
company = CIKScraper("TSN", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year, 'TSN')
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['&#8226; different regulatory structures and unexpected changes in regulatory environments; ', 'Information technology is an important part of our business operations, and we rely on information technology systems to manage business data and increase efficiencies in our production and distribution facilities and inventory management processes. We also use information technology to process financial information and results of operations for internal reporting purposes and to comply with regulatory, legal and tax requirements. In addition, we depend on information technology for digital marketing and electronic communications between our facilities, personnel, customers and suppliers, including ordering and managing raw materials and inputs, receiving and processing purchase orders, shipping products to customers and processing other transactions. Communications between our facilities, personnel, customers and suppliers may include and is not limited t
# ...

# %%
company = CIKScraper("TSN", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()
url
# Out:
# ['https://www.sec.gov/Archives/edgar/data/100493/0000100493-23-000105.txt']

# %%
company.cik
# Out:
# '100493'

# %%
# No annual report in year 2023
company = CIKScraper("TSN", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, 2022, FILE, headers)
url = scraper.scrape_sec_data()[0]
url
# Out:
# 'https://www.sec.gov/Archives/edgar/data/100493/0000100493-22-000097.txt'

# %%
data_rc = {
'ticker': 'TSN',
'year': Year,
'file': FILE,
'regulatory_compliance_key': [parser.regulatorycompliance]
}

df_rc = pd.DataFrame(data_rc)

# %%
parser.regulatorycompliance
# Out:
# {'Risks Related to Regulation and Litigation ': 'We could be subject to adverse publicity or claims from consumers. Certain of our products contain ingredients which are the subject of public scrutiny, including the suggestion that consumption may have adverse health effects. Although we strive to respond to consumer preferences and social expectations, we may not be successful in these efforts. An unfavorable report on the effects of ingredients present in our products, product recalls, such as the Jif peanut butter product recall, or negative publicity or litigation could influence consumer preferences, significantly reduce the demand for our products, and adversely affect our profitability. We may also be subject to complaints from or litigation by consumers who allege food and beverage-related illness, or other quality, health, or operational concerns. Adverse publicity resulting from such allegations could materially adversely affect us, regardless of whether such allegations ar
# ...

# %%
data_pp = {
'ticker': 'TSN',
'year': Year,
'file': FILE,
'product_portfolio': [parser.productportfolio]
}
df_pp = pd.DataFrame(data_pp)
df_pp
# Out:
#   ticker  year  file                                  product_portfolio
# 0    TSN  2023  10-K  {'In order to remain competitive, companies in...

# %%
df_rc
# Out:
#   ticker  year  file                          regulatory_compliance_key
# 0    TSN  2023  10-K  {'Risks Related to Regulation and Litigation '...

# %%
data_ai = {
'ticker': 'TSN',
'year': Year,
'file': FILE,
'acquisition_info': [parser.acquisitions]
}
df_ai = pd.DataFrame(data_ai)
df_ai
# Out:
#   ticker  year  file                                   acquisition_info
# 0    TSN  2023  10-K  [A company’s internal control over financial r...

# %% [markdown]
# #### 17. JM Smucker

# %%
company = CIKScraper("SJM", headers)
company.parsing_tickers()

scraper = SECScraper(company.cik, Year, FILE, headers)
url = scraper.scrape_sec_data()[0]

parser = DocScraper(url, FILE, headers, api_key, Year, "SJM")
parser.parsing_file()
print("Regulatory Compliance:", parser.regulatorycompliance.keys())
print("Product Portfolio:", parser.productportfolio.keys())
print("acquisitions:", parser.acquisitions[:20])
# Out:
# Regulatory Compliance: dict_keys(['Risks Related to Regulation and Litigation '])
# Product Portfolio: dict_keys(['In order to remain competitive, companies in the food industry need to consider emerging consumer preferences, technological advances, product and packaging innovations, and the growth of certain retail channels, such as the ', 'and Fancy Feast ', 'Iams and Sheba ', 'Blue Buffalo and Nudges ', 'Dentastix and Greenies ', 'Maxwell House and Yuban ', 'Private label brands Various ', 'Maxwell House and Gevalia ', 'Private label brands Various, including Diamond Crystal Brands ', 'Enhance Workplace Diversity ', 'Increase Equity Through Expanded Opportunities ', 'Foster an Inclusive Workplace '])
# ...
