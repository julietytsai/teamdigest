# %% [markdown]
# ### OSHA Scraper Workbook

# %% [markdown]
# ### 1. Statement

# %% [markdown]
# This workbook is an illustration on extracting, formulating, and exporting companies' data from OSHA database. The following codes are only for internal use of ABB's consulting practicum project and research purpose. For more details of the data source, please refer to https://www.osha.gov/ords/imis/establishment.html.

# %% [markdown]
# ### 2. Code

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlencode
import urllib.parse
from copy import copy

# %% [markdown]
# #### 2.1 Scrape index

# %% [markdown]
# ##### 2.1.1 *get_osha_url(query, start_date_str, end_date_str)*

# %% [markdown]
# The `get_sha_url()` functin returns the violation information given the company names, start date, and end date.

# %%
def get_osha_url(query, start_date_str, end_date_str):

    results_per_page = 1000
    start_date = pd.to_datetime(start_date_str)
    end_date = pd.to_datetime(end_date_str)

    # make params dictionary
    base_url = f"https://www.osha.gov/ords/imis/establishment.search"
    params = {
        'establishment': '+'.join(query.split()),
        'state': "all",
        'officetype': "all",
        'office': "all",
        'sitezip': 100000,
        'startmonth': start_date.month,
        'startday': start_date.day,
        'startyear': start_date.year,
        'endmonth': end_date.month,
        'endday': end_date.day,
        'endyear': end_date.year,
        'p_case': "all",
        'p_sort': 12,
        'p_desc': "DESC",
        'p_direction': "Prev",
        'p_show': results_per_page,
        'p_violations_exist': "yes"
    }

    return base_url + '?' + urlencode(params)

# %% [markdown]
# ##### 2.1.2 *get_index_table(osha_url)*

# %% [markdown]
# The `get_index_table()` fetch the tables within the results given the osha url.

# %%
def get_index_table(osha_url):
    tables = pd.read_html(osha_url)
    if len(tables) >= 3:
      return tables[2]
    # Continue with your DataFrame processing
    else:
      return("Insufficient tables in the HTML content.")

# %%
df = pd.read_excel("master_excel_all_variables.xlsx", sheet_name='master_excel_all_variables')
companies = df['company_name_OSHA'].tolist()
companies = [entry.replace('\r', '') if isinstance(entry, str) else entry for entry in companies]
companies = [entry for entry in companies if not (isinstance(entry, float))]

# %%
# Specify the start date and end date
date_start = '2018-11-18'
date_end = '2023-11-18'

# %% [markdown]
# The following queries are the inputs of get_osha_url() function.

# %%
queries = [(company, date_start, date_end) for company in companies]
queries
# Out:
# [('Archer Daniels Midland', '2018-11-18', '2023-11-18'),
#  ('American Crystal Sugar', '2018-11-18', '2023-11-18'),
#  ('Anheuser Busch', '2018-11-18', '2023-11-18'),
#  ('B&G Foods', '2018-11-18', '2023-11-18'),
#  ('Blue Bell Creameries, L. P', '2018-11-18', '2023-11-18'),
#  ('Brakebush Brothers, Inc.', '2018-11-18', '2023-11-18'),
#  ('Brown-Forman', '2018-11-18', '2023-11-18'),
#  ('Bunge North America', '2018-11-18', '2023-11-18'),
#  ('California Dairies Inc\n', '2018-11-18', '2023-11-18'),
#  ('Campbell Soup', '2018-11-18', '2023-11-18'),
#  ('Cargill, Incorporated', '2018-11-18', '2023-11-18'),
#  ('Cheese Merchants Of America Llc', '2018-11-18', '2023-11-18'),
#  ('Chobani, Llc\n', '2018-11-18', '2023-11-18'),
#  ('Colgate Palmolive Company', '2018-11-18', '2023-11-18'),
#  ('Conagra ', '2018-11-18', '2023-11-18'),
#  ('Corteva Agriscience', '2018-11-18', '2023-11-18'),
#  ('Country Fresh, Llc', '2018-11-18', '2023-11-18'),
#  ('Darigold Inc', '2018-11-18', '2023-11-18'),
#  ('Dsm Nutritional Products', '2018-11-18', '2023-11-18'),
#  ('E. & J. Gallo Winery', '2018-11-18', '2023-11-18'),
#  ('Ferrara Candy Company', '2018-11-18', '2023-11-18'),
#  ('General Mills', '2018-11-18', '2023-11-18'),
#  ('Hp Hood Llc', '2018-11-18', '2023-11-18'),
#  ('Ingredion', '2018-11-18', '2023-11-18'),
#  ('J.R. Simplot Co', '2018-11-18', '2023-11-18'),
#  ('Jbs Usa\n', '2018-11-18', '2023-11-18'),
#  ('Kraft-Heinz Foods Company', '2018-11-18', '2023-11-18'),
#  ("Land O' Lakes, Inc.\n", '2018-11-18', '2023-11-18'),
#  ('Leprino Foods Company\n', '2018-11-18', '2023-11-18'),
#  ('Mccain Foods Usa, Inc.\n', '2018-11-18', '2023-11-18'),
#  ('Constellation Brands, Inc.\n', '2018-11-18', '2023-11-18'),
#  ('Mondelez Global Llc\n', '2018-11-18', '2023-11-18'),
#  ('Morton Salt, Inc.\n', '2018-11-18', '2023-11-18'),
#  ('National Beef Packing Company, Llc', '2018-11-18', '2023-11-18'),
#  ('Nestle Usa, Inc.\n', '2018-11-18', '2023-11-18'),
#  ('Olam International\n', '2018-11-18', '2023-11-18'),
#  ('Pepsico, Inc\n', '2018-11-18', '2023-11-18'),
#  ('Prairie Farms Dairy, Inc.\n', '2018-11-18', '2023-11-18'),
#  ('Rich Products Corporation\n', '2018-11-18', '2023-11-18'),
#  ('Saputo Cheese Usa', '2018-11-18', '2023-11-18'),
#  ('Smithfield Foods\n', '2018-11-18', '2023-11-18'),
#  ('Tate & Lyle Ingredients Americas Llc\n', '2018-11-18', '2023-11-18'),
#  ('Western Sugar Cooperative', '2018-11-18', '2023-11-18'),
#  ('Trident Seafoods Corporation\n', '2018-11-18', '2023-11-18'),
#  ('Tyson Foods, Inc.', '2018-11-18', '2023-11-18'),
#  ('Unilever', '2018-11-18', '2023-11-18'),
#  ('J.M. Smucker Llc\n', '2018-11-18', '2023-11-18')]

# %% [markdown]
# ##### 2.1.3 *get_activities_df(query)*

# %% [markdown]
# The get_activities_df() function uses queries as its only argument, and returns a list of records of violations of a specific companies. By using a for loop, we can combine the companies' violation information in the `activities_df` table.

# %%
activities_df = []

def get_activities_df(query):
    establishment, start, end = query
    osha_url = get_osha_url(establishment, start, end)

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    try:
        response = requests.get(osha_url, headers=headers)
        tables = pd.read_html(response.content)

        if not tables:
            print(f"No tables found for {query}")
            return None

        index_df_for_this_query = tables[1]
        index_df_for_this_query = index_df_for_this_query.drop(columns=['Unnamed: 0', '#'])

        index_df_for_this_query['query'] = establishment
        index_df_for_this_query['query_start'] = start
        index_df_for_this_query['query_end'] = end

        print(f"Found {len(index_df_for_this_query)} results for {query}\n")
        return index_df_for_this_query

    except Exception as e:
        print(f"Error processing {query}: {e}")
        return None
    
for query in queries:
    activities_df_for_query = get_activities_df(query)

    if activities_df_for_query is not None:
        activities_df.append(activities_df_for_query)

activities_df = pd.concat(activities_df)
# activities_df.to_csv('data/activities_df.csv', index=False)
activities_df
# Out:
# Found 12 results for ('Archer Daniels Midland', '2018-11-18', '2023-11-18')
#
# Found 4 results for ('American Crystal Sugar', '2018-11-18', '2023-11-18')
#
# Found 7 results for ('Anheuser Busch', '2018-11-18', '2023-11-18')
#
# Found 3 results for ('B&G Foods', '2018-11-18', '2023-11-18')
#
# Found 3 results for ('Blue Bell Creameries, L. P', '2018-11-18', '2023-11-18')
#
# Found 5 results for ('Brakebush Brothers, Inc.', '2018-11-18', '2023-11-18')
#
# Found 3 results for ('Brown-Forman', '2018-11-18', '2023-11-18')
#
# Found 7 results for ('Bunge North America', '2018-11-18', '2023-11-18')
#
# Found 2 results for ('California Dairies Inc\n', '2018-11-18', '2023-11-18')
#
# Found 2 results for ('Campbell Soup', '2018-11-18', '2023-11-18')
#
# Found 4 results for ('Cargill, Incorporated', '2018-11-18', '2023-11-18')
#
# Found 2 results for ('Cheese Merchants Of America Llc', '2018-11-18', '2023-11-18')
#
# Found 2 results for ('Chobani, Llc\n', '2018-11-18', '2023-11-18')
#
# Error processing ('Colgate Palmolive Company', '2018-11-18', '2023-11-18'): No tables found
# Found 27 results for ('Conagra ', '2018-11-18', '2023-11-18')
#
# Found 2 results for ('Corteva Agriscience', '2018-11-18', '2023-11-18')
#
# Error processing ('Country Fresh, Llc', '2018-11-18', '2023-11-18'): No tables found
# Found 10 results for ('Darigold Inc', '2018-11-18', '2023-11-18')
#
# Error processing ('Dsm Nutritional Products', '2018-11-18', '2023-11-18'): No tables found
# Found 4 results for ('E. & J. Gallo Winery', '2018-11-18', '2023-11-18')
#
# Found 5 results for ('Ferrara Candy Company', '2018-11-18', '2023-11-18')
#
# Found 8 results for ('General Mills', '2018-11-18', '2023-11-18')
#
# Found 5 results for ('Hp Hood Llc', '2018-11-18', '2023-11-18')
#
# Found 6 results for ('Ingredion', '2018-11-18', '2023-11-18')
#
# Found 1 results for ('J.R. Simplot Co', '2018-11-18', '2023-11-18')
#
# Found 5 results for ('Jbs Usa\n', '2018-11-18', '2023-11-18')
#
# Found 6 results for ('Kraft-Heinz Foods Company', '2018-11-18', '2023-11-18')
#
# Found 9 results for ("Land O' Lakes, Inc.\n", '2018-11-18', '2023-11-18')
#
# Found 7 results for ('Leprino Foods Company\n', '2018-11-18', '2023-11-18')
#
# Found 2 results for ('Mccain Foods Usa, Inc.\n', '2018-11-18', '2023-11-18')
#
# Found 1 results for ('Constellation Brands, Inc.\n', '2018-11-18', '2023-11-18')
#
# Found 1 results for ('Mondelez Global Llc\n', '2018-11-18', '2023-11-18')
#
# Found 5 results for ('Morton Salt, Inc.\n', '2018-11-18', '2023-11-18')
#
# Found 4 results for ('National Beef Packing Company, Llc', '2018-11-18', '2023-11-18')
#
# Found 5 results for ('Nestle Usa, Inc.\n', '2018-11-18', '2023-11-18')
#
# Error processing ('Olam International\n', '2018-11-18', '2023-11-18'): No tables found
# Found 5 results for ('Pepsico, Inc\n', '2018-11-18', '2023-11-18')
#
# Found 17 results for ('Prairie Farms Dairy, Inc.\n', '2018-11-18', '2023-11-18')
#
# Found 15 results for ('Rich Products Corporation\n', '2018-11-18', '2023-11-18')
#
# Found 8 results for ('Saputo Cheese Usa', '2018-11-18', '2023-11-18')
#
# Found 17 results for ('Smithfield Foods\n', '2018-11-18', '2023-11-18')
#
# Found 1 results for ('Tate & Lyle Ingredients Americas Llc\n', '2018-11-18', '2023-11-18')
#
# Found 5 results for ('Western Sugar Cooperative', '2018-11-18', '2023-11-18')
#
# Found 11 results for ('Trident Seafoods Corporation\n', '2018-11-18', '2023-11-18')
#
# Found 18 results for ('Tyson Foods, Inc.', '2018-11-18', '2023-11-18')
#
# Found 2 results for ('Unilever', '2018-11-18', '2023-11-18')
#
# Found 1 results for ('J.M. Smucker Llc\n', '2018-11-18', '2023-11-18')
#        Activity Date Opened     RID  ST       Type    Scope     SIC   NAICS  \
# 0   1664999.015  04/21/2023  524500  IL    Fat/Cat  Partial     NaN  311224
# 1   1662897.015  04/12/2023  524500  IL    Fat/Cat  Partial     NaN  311224
# 2   1659430.015  03/24/2023  452110  KY  Complaint  Partial  2899.0  325998
# 3   1643826.015  01/13/2023  524500  IL   Referral  Partial     NaN  311221
# 4   1641641.015  01/04/2023  728900  NE   Referral  Partial     NaN  311224
# ..          ...         ...     ...  ..        ...      ...     ...     ...
# 16  1383619.015  03/07/2019  729300  MO   Referral  Partial     NaN  311615
# 17  1377139.015  02/07/2019  626300  TX  Complaint  Partial     NaN  311615
# 0   1472257.015  04/13/2020  728500  MO    Fat/Cat  Partial     NaN  311919
# 1   1386411.015  03/20/2019  521700  IL   Referral  Partial     NaN  311941
# 0   1666264.015  04/27/2023  454715  TN   Referral  Partial     NaN  311911
#
#     Violations                    Establishment Name                   query  \
# 0            4        Archer-Daniels-Midland Company  Archer Daniels Midland
# 1            1        Archer-Daniels-Midland Company  Archer Daniels Midland
# 2            1     65986 - Archer Daniels Midland Co  Archer Daniels Midland
# 3            1        Archer-Daniels-Midland Company  Archer Daniels Midland
# 4            4        Archer Daniels Midland Company  Archer Daniels Midland
# ..         ...                                   ...                     ...
# 16           3                     Tyson Foods, Inc.       Tyson Foods, Inc.
# 17           1                     Tyson Foods, Inc.       Tyson Foods, Inc.
# 0            1                              Unilever                Unilever
# 1            1  Unilever Illinois Manufacturing, Llc                Unilever
# 0            2                      J.M. Smucker Llc      J.M. Smucker Llc\n
#
#    query_start   query_end
# 0   2018-11-18  2023-11-18
# 1   2018-11-18  2023-11-18
# 2   2018-11-18  2023-11-18
# 3   2018-11-18  2023-11-18
# 4   2018-11-18  2023-11-18
# ..         ...         ...
# 16  2018-11-18  2023-11-18
# 17  2018-11-18  2023-11-18
# 0   2018-11-18  2023-11-18
# 1   2018-11-18  2023-11-18
# 0   2018-11-18  2023-11-18
#
# [269 rows x 13 columns]

# %% [markdown]
# #### 2.2 Scrape individual activities pages

# %% [markdown]
# After getting the records of violation activities for each company, we now further explore the details in each individual activity. For example, the `violation items`, `violation summary`, and other `related activities` could also be found in this table. Therefore, we need several functions to extract the corresponding details of each activity.

# %%
# Figure out how to scrape individual activity
def get_related_activity_table(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(url, headers=headers)
    tables = pd.read_html(response.content, match="Related Activity")
    return tables[0]

def get_violation_summary_table(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(url, headers=headers)
    tables= pd.read_html(response.content,match="Violation Summary")

    return tables[0]

def get_violation_items_table(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(url, headers=headers)
    tables= pd.read_html(response.content,match="Violation Items")

    return tables[0]

def get_investigated_inspection_table(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(url, headers=headers)
    tables = pd.read_html(response.content, match="Investigated Inspection")
    return tables[0]

def extract_key_value(tag):
    assert ':' in tag.text
    assert tag.find('strong')

    key = tag.text.split(':')[0].strip()
    value = tag.text.split(':')[1].strip()
    return key, value

def get_main_container(inspection_url):
    # get HTML from inspection page
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(inspection_url,headers=headers)
    html_doc = response.text
    soup = BeautifulSoup(html_doc, 'html.parser')

    # get main container (ignore footer/header/etc...)
    html_main_container = soup.find(id="maincontain")

    return html_main_container

def has_investigation_summary(html_main_container):
    h4s = html_main_container.find_all('h4')
    for h4 in h4s:
        if h4.text.strip() == "Investigation Summary":
            return True
    return False

def get_details(html_main_container):

    # Delete anything after "Investigation Summary H4"
    # we will scrape that stuff in a separate function
    h4s = html_main_container.find_all('h4')
    for h4 in h4s:
        if h4.text == "Investigation Summary":
            for e in h4.find_all_next():
                e.clear()

    # get details
    details = {}

    # get case status
    html_wells = html_main_container.find_all("div", class_="well")
    try:
        assert len(html_wells) == 2
        assert html_wells[0] == html_wells[1]
        case_status = html_wells[0]
        key, value = extract_key_value(case_status)
    except:
        key = 'Case Status'
        value = 'ERROR'
        print("ERROR - couldn't scrape case status")
    details[key] = value

    # get remaining details
    html_spans = html_main_container.find_all("div", class_="span4")
    for span in html_spans:
        html_p_tags = span.find_all('p')
        if len(html_p_tags) == 0:
            columns_without_colon = 0
            key, value = extract_key_value(span)
            details[key] = value
        else:
            for p_tag in html_p_tags:
                key, value = extract_key_value(p_tag)
                details[key] = value

    return details

def get_investigation_summary_details(html_main_container):
    # Delete anything after "Investigation Summary H4"
    # we will scrape that stuff in a separate function
    h4s = copy(html_main_container).find_all('h4')
    for h4 in h4s:
        if h4.text == "Investigation Summary":
            for e in h4.find_previous_siblings():
                e.decompose()

    details = {}

    spans = html_main_container.find_all('div', class_='span4')
    p_tags = html_main_container.find_all('p')
    spans_and_ptags = spans + p_tags

    details = {}
    notes_columns = 0
    for tag in spans_and_ptags:
        if ':' in tag.text and tag.find('strong'):
            key, value = extract_key_value(tag)
        else:
            notes_columns += 1
            key = f"investigation_summary_notes_{notes_columns}"
            value = tag.text
        details[key] = value

    return(details)

# %% [markdown]
# Then we create different lists to store the details.

# %%
violation_summary_tables = []
violation_items_tables = []
related_activity_tables = []
details_dictionaries = []
investigated_inspections_table = []

for index, row in activities_df.reset_index(drop=True).iterrows():
    activity_code = row['Activity']
    establishment=row['Establishment Name']
    url = f"https://www.osha.gov/ords/imis/establishment.inspection_detail?id={activity_code}"
    print(f"{index} of {len(activities_df)} - scraping {url}")

    violation_summary = get_violation_summary_table(url)
    violation_summary['activity_code'] = activity_code
    violation_summary['establishment'] = establishment
    violation_summary_tables.append(violation_summary)
    #print(violation_summary)
    violation_items = get_violation_items_table(url)
    violation_items['activity_code'] = activity_code
    violation_items['establishment'] = establishment
    violation_items_tables.append(violation_items)

    try:
        related_activity = get_related_activity_table(url)
        related_activity['activity_code'] = activity_code
        related_activity['establishment'] = establishment
        related_activity_tables.append(related_activity)
    except:
        print("ERROR - related activity table wasn't scraped")


    html = get_main_container(url)
    details = {}

    if has_investigation_summary(html):
        print("Has investigation summary")
        investigation_summary_details = get_investigation_summary_details(html)
        details.update(investigation_summary_details)

        investigated_inspections = get_investigated_inspection_table(url)
        investigated_inspections['activity_code'] = activity_code
        investigated_inspections['establishment'] = establishment
        investigated_inspections_table.append(investigated_inspections)


    details.update(get_details(html))
    details['activity_code'] = activity_code
    details['establishment'] = establishment
    details_dictionaries.append(details)
# Out:
# 0 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1664999.015
# 1 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1662897.015
# Has investigation summary
# 2 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1659430.015
# 3 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1643826.015
# 4 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1641641.015
# 5 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1627196.015
# 6 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1610433.015
# ERROR - related activity table wasn't scraped
# 7 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1587740.015
# 8 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1583701.015
# Has investigation summary
# 9 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1554333.015
# 10 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1475965.015
# 11 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1387624.015
# 12 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1658963.015
# 13 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1608314.015
# 14 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1513727.015
# 15 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1475098.015
# 16 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1562193.015
# ERROR - related activity table wasn't scraped
# 17 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1539718.015
# 18 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1499644.015
# ERROR - related activity table wasn't scraped
# 19 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1441747.015
# Has investigation summary
# 20 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1398352.015
# Has investigation summary
# 21 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1385495.015
# ERROR - related activity table wasn't scraped
# 22 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1367236.015
# 23 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1572706.015
# 24 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1524740.015
# 25 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1373821.015
# Has investigation summary
# 26 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1517709.015
# 27 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1517862.015
# 28 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1451228.015
# Has investigation summary
# 29 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1642125.015
# 30 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1606965.015
# 31 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1593660.015
# ERROR - related activity table wasn't scraped
# 32 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1562675.015
# 33 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1481591.015
# 34 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1675056.015
# 35 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1656836.015
# ERROR - related activity table wasn't scraped
# 36 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1513653.015
# 37 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1552850.015
# Has investigation summary
# 38 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1497511.015
# ERROR - related activity table wasn't scraped
# 39 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1488178.015
# Has investigation summary
# 40 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1466459.015
# ERROR - related activity table wasn't scraped
# 41 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1457249.015
# ERROR - related activity table wasn't scraped
# 42 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1443879.015
# 43 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1361411.015
# 44 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1617461.015
# 45 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1615506.015
# 46 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1430149.015
# 47 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1389976.015
# Has investigation summary
# 48 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1641554.015
# 49 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1515654.015
# 50 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1421453.015
# 51 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1369086.015
# Has investigation summary
# 52 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1515432.015
# 53 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1361314.015
# Has investigation summary
# 54 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1496649.015
# 55 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1384972.015
# ERROR - related activity table wasn't scraped
# 56 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1681531.015
# 57 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1662685.015
# 58 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1635750.015
# 59 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1609884.015
# 60 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1613779.015
# 61 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1584508.015
# 62 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1563721.015
# 63 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1562974.015
# Has investigation summary
# 64 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1553143.015
# 65 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1553132.015
# 66 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1537696.015
# 67 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1533045.015
# 68 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1531760.015
# 69 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1531481.015
# 70 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1528249.015
# 71 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1501845.015
# 72 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1497295.015
# 73 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1491638.015
# 74 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1482856.015
# 75 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1475045.015
# 76 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1472729.015
# Has investigation summary
# 77 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1450640.015
# 78 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1413117.015
# 79 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1400362.015
# 80 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1389163.015
# 81 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1371895.015
# Has investigation summary
# 82 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1371835.015
# 83 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1627298.015
# 84 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1499054.015
# 85 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1635567.015
# 86 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1615898.015
# 87 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1630558.015
# 88 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592234.015
# 89 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1591680.015
# 90 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1528545.015
# 91 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1488890.015
# 92 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1468914.015
# 93 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1445177.015
# 94 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1402457.015
# 95 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1554796.015
# 96 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1534370.015
# 97 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1435293.015
# Has investigation summary
# 98 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1370386.015
# Has investigation summary
# 99 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1588430.015
# 100 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1582482.015
# 101 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1456731.015
# Has investigation summary
# 102 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1445998.015
# Has investigation summary
# 103 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1411466.015
# Has investigation summary
# 104 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1682999.015
# 105 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1577810.015
# 106 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1574785.015
# Has investigation summary
# 107 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1574158.015
# Has investigation summary
# 108 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1558022.015
# Has investigation summary
# 109 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1541106.015
# 110 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1525388.015
# 111 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1366181.015
# Has investigation summary
# 112 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1607826.015
# 113 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1603854.015
# 114 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1565331.015
# ERROR - related activity table wasn't scraped
# 115 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1544103.015
# 116 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1447084.015
# ERROR - related activity table wasn't scraped
# 117 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1656307.015
# 118 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1656343.015
# 119 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1573039.015
# 120 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1565912.015
# 121 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1493574.015
# 122 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1456668.015
# ERROR - related activity table wasn't scraped
# 123 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1628115.015
# 124 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1640089.015
# ERROR - related activity table wasn't scraped
# 125 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1583681.015
# Has investigation summary
# 126 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1572987.015
# Has investigation summary
# 127 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1472850.015
# 128 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1463808.015
# 129 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1656470.015
# 130 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1643285.015
# 131 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1610654.015
# ERROR - related activity table wasn't scraped
# 132 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592816.015
# 133 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1560762.015
# 134 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1466095.015
# ERROR - related activity table wasn't scraped
# 135 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1657091.015
# 136 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1657097.015
# 137 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1640589.015
# 138 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1560356.015
# Has investigation summary
# 139 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1487568.015
# Has investigation summary
# 140 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1446224.015
# ERROR - related activity table wasn't scraped
# 141 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1371418.015
# 142 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1367360.015
# Has investigation summary
# 143 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1364038.015
# ERROR - related activity table wasn't scraped
# 144 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1607214.015
# 145 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1571948.015
# Has investigation summary
# 146 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1498068.015
# 147 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1481335.015
# 148 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1413631.015
# ERROR - related activity table wasn't scraped
# 149 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1372872.015
# Has investigation summary
# 150 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1369964.015
# Has investigation summary
# 151 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1633643.015
# 152 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1534224.015
# 153 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1661577.015
# ERROR - related activity table wasn't scraped
# 154 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1492387.015
# 155 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1617997.015
# 156 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1531367.015
# 157 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1511380.015
# 158 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1478692.015
# 159 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1365937.015
# Has investigation summary
# 160 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1688505.015
# 161 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1608345.015
# 162 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1599740.015
# 163 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1421092.015
# ERROR - related activity table wasn't scraped
# 164 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1652719.015
# 165 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1632624.015
# 166 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592428.015
# 167 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1403921.015
# Has investigation summary
# 168 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1369203.015
# Has investigation summary
# 169 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1570968.015
# Has investigation summary
# 170 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1446388.015
# 171 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1416027.015
# 172 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1413446.015
# 173 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1382833.015
# ERROR - related activity table wasn't scraped
# 174 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1654014.015
# ERROR - related activity table wasn't scraped
# 175 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1654021.015
# ERROR - related activity table wasn't scraped
# 176 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1611475.015
# 177 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592289.015
# ERROR - related activity table wasn't scraped
# 178 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1592287.015
# 179 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1588417.015
# 180 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1559435.015
# Has investigation summary
# 181 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1497574.015
# Has investigation summary
# 182 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1480956.015
# Has investigation summary
# 183 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1475190.015
# 184 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1461725.015
# 185 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1462260.015
# 186 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1411796.015
# Has investigation summary
# 187 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1390015.015
# 188 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1381101.015
# 189 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1378059.015
# 190 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1368865.015
# 191 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1671690.015
# 192 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1671592.015
# 193 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1657561.015
# ERROR - related activity table wasn't scraped
# 194 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1617553.015
# 195 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1585196.015
# ERROR - related activity table wasn't scraped
# 196 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1545578.015
# 197 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1543088.015
# Has investigation summary
# 198 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1515904.015
# 199 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1493853.015
# ERROR - related activity table wasn't scraped
# 200 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1414628.015
# Has investigation summary
# 201 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1392282.015
# 202 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1392221.015
# 203 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1386445.015
# Has investigation summary
# 204 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1379029.015
# 205 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1376792.015
# 206 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1670356.015
# 207 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1655539.015
# 208 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1639630.015
# 209 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1536460.015
# 210 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1440752.015
# Has investigation summary
# 211 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1436614.015
# Has investigation summary
# 212 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1432961.015
# 213 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1431540.015
# Has investigation summary
# 214 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1673158.015
# ERROR - related activity table wasn't scraped
# 215 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1656341.015
# 216 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1625950.015
# 217 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1581467.015
# Has investigation summary
# 218 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1573289.015
# Has investigation summary
# 219 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1559231.015
# Has investigation summary
# 220 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1541093.015
# 221 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1537555.015
# 222 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1534843.015
# 223 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1529234.015
# 224 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1513015.015
# 225 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1511330.015
# 226 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1506467.015
# Has investigation summary
# 227 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1506240.015
# Has investigation summary
# 228 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1476723.015
# 229 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1452183.015
# Has investigation summary
# 230 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1392813.015
# Has investigation summary
# 231 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1537244.015
# 232 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1633343.015
# Has investigation summary
# 233 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1526599.015
# 234 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1437881.015
# 235 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1383884.015
# Has investigation summary
# 236 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1384981.015
# 237 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1663887.015
# 238 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1654985.015
# 239 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1584864.015
# 240 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1585167.015
# 241 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1471970.015
# 242 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1470247.015
# ERROR - related activity table wasn't scraped
# 243 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1470408.015
# 244 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1452776.015
# 245 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1416891.015
# 246 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1416870.015
# 247 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1368392.015
# Has investigation summary
# 248 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1645531.015
# 249 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1642395.015
# 250 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1639823.015
# 251 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1626601.015
# 252 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1610057.015
# Has investigation summary
# 253 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1598212.015
# 254 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1597511.015
# 255 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1588983.015
# 256 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1582860.015
# 257 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1577755.015
# 258 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1572930.015
# Has investigation summary
# 259 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1559738.015
# 260 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1539393.015
# 261 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1497467.015
# 262 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1409842.015
# Has investigation summary
# 263 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1388622.015
# Has investigation summary
# 264 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1383619.015
# Has investigation summary
# 265 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1377139.015
# 266 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1472257.015
# Has investigation summary
# 267 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1386411.015
# Has investigation summary
# 268 of 269 - scraping https://www.osha.gov/ords/imis/establishment.inspection_detail?id=1666264.015

# %%
violation_summary_df = pd.concat(violation_summary_tables)
violation_items_df = pd.concat(violation_items_tables)
related_activity_df = pd.concat(related_activity_tables)
investigated_inspections_df = pd.concat(investigated_inspections_table)
details_df = pd.DataFrame(details_dictionaries)

# %% [markdown]
# Specifically, we only focus a 6 categories of violations sorted by the `Standard Cited` column of violation_items table. The encoding of each category of violations could be viewed on https://www.osha.gov/laws-regs/federalregister/standardnumber/1910. Therefore, we map the category name into the violation_items_df table.

# %%
mapping_dict = {
    '19100269': 'Electric Power Generation, Transmission, and Distribution',
    '19100333': 'Selection and use of work practices',
    '19100334': 'Use of equipment',
    '19100335': 'Safeguards for personnel protection',
    '19100137': 'Electrical Protective Equipment',
    '19100147': 'The control of hazardous energy (lockout/tagout)'
}

# %%
filtered_violation_items_df = violation_items_df[violation_items_df['Standard Cited'].str.startswith(tuple(mapping_dict.keys()))]
filtered_violation_items_df['Citation Category'] = filtered_violation_items_df['Standard Cited'].apply(lambda x: mapping_dict.get(x.split()[0], None))
filtered_violation_items_df = filtered_violation_items_df[['Citation ID', 'Standard Cited', 'Issuance Date','activity_code', 'establishment','Citation Category']]
filtered_violation_items_df
# Out:
# C:\Users\xben4\AppData\Local\Temp\ipykernel_33008\226249089.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_violation_items_df['Citation Category'] = filtered_violation_items_df['Standard Cited'].apply(lambda x: mapping_dict.get(x.split()[0], None))
#    Citation ID      Standard Cited Issuance Date  activity_code  \
# 0         1001      19100147 C04 I    03/20/2023    1627196.015
# 1         1002        19100147 D06    03/20/2023    1627196.015
# 0       01001A      19100147 C04 I    06/22/2021    1513727.015
# 1       01001B      19100147 C07 I    06/22/2021    1513727.015
# 0       01001A   19100147 C04 II B    11/30/2021    1539718.015
# ..         ...                 ...           ...            ...
# 2       01001C      19100147 C06 I    04/25/2022    1572930.015
# 0         1001  19100147 C07 III B    12/18/2020    1497467.015
# 2         2001    19100147 C07 I A    04/08/2019    1383619.015
# 0         1001      19100147 C04 I    06/21/2023    1666264.015
# 1         2001     19100147 C06 II    06/21/2023    1666264.015
#
#                                         establishment  \
# 0                              Archer Daniels Midland
# 1                              Archer Daniels Midland
# 0                              American Crystal Sugar
# 1                              American Crystal Sugar
# 0                                Anheuser-Busch, Llc.
# ..                                                ...
# 2                                   Tyson Foods, Inc.
# 0   The Hillshire Brands Company Dba Tyson Foods Inc.
# 2                                   Tyson Foods, Inc.
# 0                                    J.M. Smucker Llc
# 1                                    J.M. Smucker Llc
#
#                                    Citation Category
# 0   The control of hazardous energy (lockout/tagout)
# 1   The control of hazardous energy (lockout/tagout)
# 0   The control of hazardous energy (lockout/tagout)
# 1   The control of hazardous energy (lockout/tagout)
# 0   The control of hazardous energy (lockout/tagout)
# ..                                               ...
# 2   The control of hazardous energy (lockout/tagout)
# 0   The control of hazardous energy (lockout/tagout)
# 2   The control of hazardous energy (lockout/tagout)
# 0   The control of hazardous energy (lockout/tagout)
# 1   The control of hazardous energy (lockout/tagout)
#
# [133 rows x 6 columns]

# %% [markdown]
# Furthermore, we also want to explore the summary of that violation activity, therefore, we can merge the filtered_violation_items_df with the details_df by `activity_code` column.

# %%
merged_df = pd.merge(filtered_violation_items_df, details_df[['activity_code', 'investigation_summary_notes_1', 'investigation_summary_notes_2', 'investigation_summary_notes_3', 'Keywords']],
                     on='activity_code', how='inner')

# %%
merged_df
# Out:
#     Citation ID      Standard Cited Issuance Date  activity_code  \
# 0          1001      19100147 C04 I    03/20/2023    1627196.015
# 1          1002        19100147 D06    03/20/2023    1627196.015
# 2        01001A      19100147 C04 I    06/22/2021    1513727.015
# 3        01001B      19100147 C07 I    06/22/2021    1513727.015
# 4        01001A   19100147 C04 II B    11/30/2021    1539718.015
# ..          ...                 ...           ...            ...
# 128      01001C      19100147 C06 I    04/25/2022    1572930.015
# 129        1001  19100147 C07 III B    12/18/2020    1497467.015
# 130        2001    19100147 C07 I A    04/08/2019    1383619.015
# 131        1001      19100147 C04 I    06/21/2023    1666264.015
# 132        2001     19100147 C06 II    06/21/2023    1666264.015
#
#                                          establishment  \
# 0                               Archer Daniels Midland
# 1                               Archer Daniels Midland
# 2                               American Crystal Sugar
# 3                               American Crystal Sugar
# 4                                 Anheuser-Busch, Llc.
# ..                                                 ...
# 128                                  Tyson Foods, Inc.
# 129  The Hillshire Brands Company Dba Tyson Foods Inc.
# 130                                  Tyson Foods, Inc.
# 131                                   J.M. Smucker Llc
# 132                                   J.M. Smucker Llc
#
#                                     Citation Category  \
# 0    The control of hazardous energy (lockout/tagout)
# 1    The control of hazardous energy (lockout/tagout)
# 2    The control of hazardous energy (lockout/tagout)
# 3    The control of hazardous energy (lockout/tagout)
# 4    The control of hazardous energy (lockout/tagout)
# ..                                                ...
# 128  The control of hazardous energy (lockout/tagout)
# 129  The control of hazardous energy (lockout/tagout)
# 130  The control of hazardous energy (lockout/tagout)
# 131  The control of hazardous energy (lockout/tagout)
# 132  The control of hazardous energy (lockout/tagout)
#
#                          investigation_summary_notes_1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128    Employee Amputates Finger In Chain And Sprocket
# 129                                                NaN
# 130  Employee Amputates Finger When Places Hand In ...
# 131                                                NaN
# 132                                                NaN
#
#     investigation_summary_notes_2  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 128
# 129                           NaN
# 130
# 131                           NaN
# 132                           NaN
#
#                          investigation_summary_notes_3  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  At 11:00 a.m. on January 6, 2022, an employee ...
# 129                                                NaN
# 130  At approximately 10:15  p.m. on March 5, 2019,...
# 131                                                NaN
# 132                                                NaN
#
#                                               Keywords
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 128  amputated, amputation, chain, conveyor, finger...
# 129                                                NaN
# 130  amputated, amputation, cleaning, finger, finge...
# 131                                                NaN
# 132                                                NaN
#
# [133 rows x 10 columns]

# %%
merged_df.to_excel('OSHA_violations.xlsx', index=False)
